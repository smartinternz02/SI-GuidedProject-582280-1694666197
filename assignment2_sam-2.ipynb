# %%
#sam pillutla
import matplotlib.pyplot as plt

#SEABORN
import seaborn as sns

#numpy & pandas
import numpy as np
import pandas as pd

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.shape
# Out:
# (51, 8)

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
#total is reffered as the total number of car_creashes/car_accidents occured.

# %% [markdown]
# #SCATTER PLOT

# %%
#SCATTER PLOT
sns.scatterplot(x="alcohol",y="total",data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='total'>

# %% [markdown]
#     #Inference: DIRECTLY PROPORTIONAL
#      The percentage of accidents involving alcohol could be a significant factor in accident rates.
#      In this graph we can observe that,as the alcohol rate increases the car_crashes also increases.

# %%
sns.scatterplot(x="speeding",y="total",data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %% [markdown]
#     #Inference: DIRECTLY PROPORTIONAL
#      Accidents may be influenced by the percentage of accidents involving speeding as a contributing factor.
#      From this graph we observe that ,more speeding-related accidents could lead to higher overall accident rates.

# %%
sns.scatterplot(x="no_previous",y="not_distracted",data=df)
# Out:
# <Axes: xlabel='no_previous', ylabel='not_distracted'>

# %% [markdown]
#       #INFERENCE: DIRECTLY PROPORTIONAL
#        As the number of drivers with no previous accidents increases, there seems to be a tendency for more not distracted drivers,
#        implying a potential direct or positive correlation.

# %% [markdown]
# #LINE PLOT

# %%
#LINE PLOT
sns.lineplot(x="alcohol",y="total",data=df,color='red')
# Out:
# <Axes: xlabel='alcohol', ylabel='total'>

# %% [markdown]
#     #Inference: DIRECTLY PROPORTIONAL
#      The percentage of accidents involving alcohol could be a significant factor in accident rates.
#      In this graph we can observe that,as the alcohol rate increases the car_crashes also increases.

# %%
sns.lineplot(x="not_distracted",y="total",data=df,color='green')
# Out:
# <Axes: xlabel='not_distracted', ylabel='total'>

# %% [markdown]
#       #Inference: INVERSLY PROPORTIONAL
#       As the percentage of accidents where drivers were not distracted (x-axis) increases, the total number of accidents (y-axis)
#       tends to decrease. This implies that a lower rate of distraction among drivers is associated with fewer accidents.

# %%
sns.lineplot(x="alcohol",y="speeding",data=df,color='blue')
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %% [markdown]
#       #INFERENCE: CORRELATION EXSISTS
#       As alcohol consumption increases, speeding tends to increase as well, indicating a positive or direct correlation
#       between the two variables.

# %%
# Create a scatterplot matrix of selected columns
selected_columns = df[['total', 'ins_losses', 'alcohol', 'speeding']]
pd.plotting.scatter_matrix(selected_columns, figsize=(8, 8),color="red")
plt.suptitle("Scatterplot Matrix of Selected Columns")
plt.show()

# %% [markdown]
#       # Inference: This matrix displays scatterplots of selected columns, allowing you to explore relationships between them.

# %% [markdown]
# #DISTINCT PLOT

# %%
#DISTINCT PLOT
sns.distplot(df['total'])
plt.show()
# Out:
# <ipython-input-18-cf1ccce7af28>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total'])

# %% [markdown]
#       #INFERENCE:
#       The distribution plot of the "total" variable indicates that it is right-skewed, with a majority of data points clustered
#       towards lower values.
#       This suggests that most states have a relatively lower number of total accidents. However, there are some outliers on the right
#       tail, representing states with higher accident rates.

# %%
sns.distplot(df["speeding"])
plt.show()
# Out:
# <ipython-input-19-048a1ded1ffc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["speeding"])

# %% [markdown]
#       INFERENCE:
#       This plot illustrates the distribution of speeding-related accidents in the dataset.
#       The distribution of "speeding" incidents is right-skewed, with a majority of regions having lower speeding rates.

# %% [markdown]
# #MULTI VARIATE

# %%
#multi  variate
sns.relplot(x="speeding",y="total",data=df,hue="alcohol")

# %% [markdown]
#       Inference:
#       As the speeding increases the rate of total crashes also increases, but there is a drasting increase in the creashes if
#       there is a high alcohol rate along with speeding.

# %% [markdown]
# #RELATION PLOT

# %%
sns.relplot(x="alcohol", y="speeding", hue="ins_premium", data=df)
plt.title("Relationship between Alcohol and Speeding with Insurance Premium")
plt.xlabel("Alcohol Involvement (%)")
plt.ylabel("Speeding Incidents")
plt.show()

# %% [markdown]
#       #INFERENCE:
#       The relational plot illustrates a potential association between higher alcohol involvement and increased speeding incidents.
#       Variations in insurance premium costs suggest that regions with elevated alcohol involvement may face diverse insurance pricing.

# %% [markdown]
# #BAR PLOT

# %%
#BAR PLOT
plt.subplots(figsize=(20,8))
sns.barplot(data=df,x="total",y="no_previous",ci=None)
plt.show()
# Out:
# <ipython-input-22-9f5c39117356>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="total",y="no_previous",ci=None)

# %% [markdown]
#       #Inference: INVERSLY PROPORTIONAL
#       As the total number of accidents (x-axis) increases, the percentage of accidents involving drivers with no previous accidents
#       (y-axis) tends to decrease.
#       This implies that a higher accident rate is associated with a lower percentage of inexperienced drivers.

# %%
plt.subplots(figsize=(20,8))
sns.barplot(data=df,x="not_distracted",y="alcohol",ci=None)
plt.show()
# Out:
# <ipython-input-23-170f2daaf348>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="not_distracted",y="alcohol",ci=None)

# %% [markdown]
#       #INFERENCE: INVERSLY PROPORTIONAL
#       Higher alcohol involvement tend to have fewer incidents of being not distracted.

# %% [markdown]
# #BOX PLOT

# %%
#BOX PLOT
plt.subplots(figsize=(20,8))
sns.boxplot(x="total", y="no_previous", data=df)

# Set labels and title
plt.xlabel("Total Accidents")
plt.ylabel("Percentage of Drivers with No Previous Accidents")
plt.title("Boxplot of Total Accidents vs. No Previous Accidents")

# Show the plot
plt.show()

# %% [markdown]
#         INFERENCE:
#         The boxplot illustrates a negative relationship between "Total Accidents" and the "Percentage of Drivers with No
#         Previous Accidents."
#         As the total number of accidents increases, there is a tendency for the percentage of drivers with no previous accidents to decrease.
#         This indicates an inverse proportionality between these variables, where higher accident rates are associated with a lower percentage
#         of inexperienced drivers.

# %%
plt.subplots(figsize=(20,5))
sns.boxplot(x="alcohol", y="no_previous", data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='no_previous'>

# %% [markdown]
#       #INFERENCE: INVERSLY PROPORTIONAL
#       The boxplot between "alcohol" and "no_previous" in the car_crashes dataset shows a notable pattern.
#       As alcohol involvement increases, the number of drivers with no previous accidents tends to decrease

# %%
# Create a box plot of 'total' accidents grouped by distracted driving status
plt.figure(figsize=(8, 6))
sns.boxplot(x="not_distracted", y="total", data=df)
plt.xlabel("Distracted Driving")
plt.ylabel("Total Accidents")
plt.title("Box Plot of Total Accidents by Distracted Driving Status")
plt.show()

# %% [markdown]
#       # Inference:
#       The boxplot between "not_distracted" and "total" accidents in the car_crashes dataset reveals that regions with higher levels
#       of not being distracted tend to have a wider range of total accidents.

# %% [markdown]
# #JOINT PLOT

# %%
# Create a joint plot
sns.jointplot(x="total", y="ins_losses", data=df, kind="scatter")

# Set labels and title
plt.xlabel("Total Accidents")
plt.ylabel("Percentage of insurance losses")
plt.suptitle("Joint Plot of Total Accidents vs. insurance losses", y=1.02)

# Show the plot
plt.show()

# %% [markdown]
#       The joint plot between "Total Accidents" and "Insurance Losses" suggests a potential positive relationship.
#       As the total number of accidents (x-axis) increases, there seems to be a tendency for higher insurance losses (y-axis).
#       However, the relationship is not strictly linear, indicating that while there's a general trend of higher accidents leading
#       to higher losses, it's not perfectly proportional and may be influenced by other factors.

# %% [markdown]
# #CORRELATION

# %%
#CORRELATION
cor=df.corr()
cor
# Out:
# <ipython-input-28-e8f18c0e6e89>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
sns.heatmap(cor,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
#       #INFERENCE:
#       The sns.heatmap for the "car_crashes" table indicates the correlation between variables. The "YlGnBu" color map helps
#       visualize the strength of these correlations, with darker shades representing stronger positive correlations,
#       while annotated values provide precise correlation coefficients.
#       -----------------------------------------------------
#       we observe high/positive relation between total and alcohol,no_previous,not_distracted,speeding.

# %% [markdown]
# #HISTOGRAM

# %%
# Create a histogram for the "Total Accidents" column
plt.hist(df['total'], bins=10, edgecolor='k')
plt.title('Histogram of Total Accidents')
plt.xlabel('Total Accidents')
plt.ylabel('Frequency')
plt.grid(True)

plt.show()

# %% [markdown]
#       The histogram of "Total Accidents" shows that the majority of states have a relatively low number of accidents, with a peak around 15-17 accidents.
#       A few states exhibit higher accident rates as indicated by the right tail of the distribution.
#       This distribution provides insights into the variation in accident frequencies among states

# %%
# Create a histogram of the 'speeding' column
# Inference: This histogram visualizes the distribution of speeding-related accidents.
plt.hist(x="speeding")
plt.show()

# %% [markdown]
# #PIE CHAT

# %%
cc = df[['alcohol', 'speeding', 'not_distracted', 'no_previous']].sum()
labels = cc.index
plt.figure(figsize=(8, 8))
plt.pie(cc, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of Factors')
plt.show()

# %%
df["total"].value_counts()
# Out:
# 14.1    2
# 12.8    2
# 13.6    2
# 21.4    2
# 19.4    2
# 23.9    2
# 14.9    1
# 14.7    1
# 11.6    1
# 11.2    1
# 18.4    1
# 12.3    1
# 16.8    1
# 19.9    1
# 17.6    1
# 18.2    1
# 11.1    1
# 19.5    1
# 11.3    1
# 12.7    1
# 10.6    1
# 23.8    1
# 13.8    1
# 16.1    1
# 18.8    1
# 9.6     1
# 18.1    1
# 18.6    1
# 22.4    1
# 12.0    1
# 10.8    1
# 16.2    1
# 5.9     1
# 17.9    1
# 15.6    1
# 17.5    1
# 15.3    1
# 14.5    1
# 15.7    1
# 17.8    1
# 20.5    1
# 15.1    1
# 12.5    1
# 8.2     1
# 17.4    1
# Name: total, dtype: int64
